# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
k = [1, 2]
x = np.linspace(0, 10, 21)
plt.plot(x, np.cos(k[1] * x),marker = "o")
plt.plot(x, np.cos(k[0] * x),marker = "o")
